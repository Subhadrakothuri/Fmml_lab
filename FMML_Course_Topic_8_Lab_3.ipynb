# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhadrakothuri/Fmml_lab/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-17 05:58:31--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   181MB/s    in 0.4s
#
# 2024-04-17 05:58:32 (181 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21969   1112.2289v1  Exact inference in the linear regression model...  stat
# 2807   1801.07226v1  We study generalization properties of distribu...  stat
# 24389   1311.3318v1  Existing methods in the semantic computer visi...    cs
# 39350  1512.00101v2  Graph-cuts are widely used in computer vision....    cs
# 19486   1107.4303v2  Effective debugging of ontologies is an import...    cs
# ...             ...                                                ...   ...
# 22146  1504.06026v1  We consider the problem of estimating undirect...  stat
# 21846   1401.0086v2  We consider forward-backward greedy algorithms...  stat
# 2574   1606.01885v1  Algorithm design is a laborious process and of...    cs
# 6494   1702.08019v1  In this paper, we consider asymptotic properti...  stat
# 10297   1110.2529v2  We study the generalization performance of onl...  stat
#
#                                                    title  year  \
# 21969  Convergent Expectation Propagation in Linear M...  2011
# 2807   Optimal Convergence for Distributed Learning w...  2018
# 24389  A Study of Actor and Action Semantic Retention...  2013
# 39350        Dynamic Parallel and Distributed Graph Cuts  2015
# 19486  Interactive ontology debugging: two query stra...  2011
# ...                                                  ...   ...
# 22146  Graphical Fermat's Principle and Triangle-Free...  2015
# 21846  Forward-Backward Greedy Algorithms for General...  2013
# 2574                                Learning to Optimize  2016
# 6494   Support vector machine and its bias correction...  2017
# 10297  The Generalization Ability of Online Algorithm...  2011
#
#                                                 keywords
# 21969  [inference, regression, intractable, expectati...
# 2807   [generalization, properties, distributed, algo...
# 24389  [community, explosion, sophisticated, detectio...
# 39350  [optimization, scalability, strandmark, introd...
# 19486  [effective, debugging, ontologies, important, ...
# ...                                                  ...
# 22146  [estimating, undirected, dimensional, distribu...
# 21846  [algorithms, selection, functions, algorithm, ...
# 2574   [algorithm, laborious, iterations, validation,...
# 6494   [asymptotic, properties, dimension, consistenc...
# 10297  [generalization, performance, algorithms, depe...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21969    [inference, regression, intractable, expectati...
# 2807     [generalization, properties, distributed, algo...
# 24389    [community, explosion, sophisticated, detectio...
# 39350    [optimization, scalability, strandmark, introd...
# 19486    [effective, debugging, ontologies, important, ...
#                                ...
# 6427     [selection, applications, microarray, predicti...
# 3979     [evolutionary, algorithms, optimization, multi...
# 21547    [introduce, efficient, optimization, subgradie...
# 21776    [informally, stochastic, learnable, generaliza...
# 19326    [inference, reasoning, uncertain, information,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8665 words.
# Out of those 4559 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="82bbf8e7-34fb-400a-846b-b61883957c6a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82bbf8e7-34fb-400a-846b-b61883957c6a")) {                    Plotly.newPlot(                        "82bbf8e7-34fb-400a-846b-b61883957c6a",                        [{"x":["approximation","inference","stationary","constraints","generated","intractable","approximate","sequential","convergent","experiments","synthetic","converges","similarly","regression","alternative","expectation","algorithm","propagation","partition","principal","nonparametric","stochastic","particularly","dependent","algorithms","component","considering","investigate","properties","convergence","theoretical","generalization","computational","complexity","distributed","reproducing","including","regularization","different","perceptions","community","recognition","processes","established","discriminate","segmentation","observers","significant","retention","scalability","extraction","systematic","supervoxels","perception","typically","potentially","detection","underlying","representation","decompositions","sophisticated","furthermore","explosion","semantics","intermediate","ultimately","processing","supervoxel","extensive","computation","introduce","polynomial","validated","guaranteed","predefined","agreement","splitting","overlapped","performance","subgraphs","framework","effectively","iterations","optimization","experimental","solutions","representations","introduced","strategies","knowledge","probabilities","ontologies","complications","demonstrates","vocabularies","formalized","significantly","distributions","debugging","diagnoses","demonstrated","superiority","scenarios","information","available","localization","efficient","interactive","effective","important","evaluation","application","performing","inappropriate","identified","qualities","selection","experimented","understanding","prerequisite","formulating","measurements","diagnosis","exploited","especially","descriptions","approaches","probability","observations","principle","described","resembling","analysing","regarding","outstanding","activation","artifacts","functioning","mechanisms","perceptrons","denoising","procedure","considered","architectures","artefactual","preprocessing","evaluations","relevance","comparing","robustness","prediction","parameter","conditions","compensating","initialization","investigating","alignment","pretraining","combination","recognizing","intuitively","excellent","evaluates","benchmark","performances","challenging","classification","architecture","effectiveness","demonstrate","biometrics","correlation","individual","transferring","correlated","applications","description","identification","representational","curriculum","attributes","advantages","performed","attribute","metaheuristic","earthquake","strengthen","reduction","connectivity","unnecessary","facilitate","estimated","reasoning","reasonable","transportation","investment","therefore","numerical","dimension","dependency"],"y":[118,208,27,163,156,30,122,73,7,581,135,23,13,100,109,30,851,91,29,30,22,131,73,85,590,103,65,134,213,119,159,117,281,236,103,12,273,99,735,4,80,357,104,46,12,205,11,225,2,33,133,39,2,47,112,45,332,119,355,10,29,177,8,87,30,11,304,2,179,137,341,69,36,30,22,18,12,5,870,5,569,139,34,344,380,155,238,130,100,356,50,26,3,56,3,10,246,125,5,7,97,40,100,695,292,63,442,41,251,351,247,237,72,6,52,6,155,12,165,4,9,56,58,38,135,39,448,186,76,45,63,2,8,38,7,32,29,6,45,7,57,136,110,120,1,27,54,55,60,86,221,139,139,2,32,16,39,5,130,31,14,26,11,200,41,285,529,221,212,555,3,58,98,17,30,457,83,94,10,7,62,100,138,36,3,2,7,103,26,6,54,54,140,36,17,5,138,96,56,41],"type":"bar"},{"x":["approximation","inference","stationary", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4559,), (4559, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.4782608695652174);'>Continuously</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneous</span> <span style=''>hyper</span> <span style=''>objects</span> <span style=''>in</span> <span style=''>cryo</span> <span style=''>EM</span> <span style=''>and</span> <span style=''>3</span> <span style=''>D</span> <span style=''>movies</span> <span style=''>of</span> <span style=''>many</span> <span style=''>temporal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensions</span> <br/><br/><span style=''>Single</span> <span style=''>particle</span> <span style=''>cryo</span> <span style=''>electron</span> <span style='background-color:rgba(0, 255, 0, 0.7);'>microscopy</span> <span style=''>(EM)</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasingly</span> <span style=''>popular</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determining</span> <span style=''>the</span> <span style=''>3</span> <span style=''>D</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>macromolecules</span> <span style=''>from</span> <span style=''>noisy</span> <span style=''>2</span> <span style=''>D</span> <span style=''>images</span> <span style=''>of</span> <span style=''>single</span> <span style=''>macromolecules</span> <span style=''>whose</span> <span style='background-color:rgba(0, 255, 0, 0.7333333333333334);'>orientations</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6153846153846154);'>positions</span> <span style=''>are</span> <span style=''>random</span> <span style=''>and</span> <span style=''>unknown</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>great</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>opportunities</span> <span style=''>in</span> <span style=''>cryo</span> <span style=''>EM</span> <span style=''>is</span> <span style=''>to</span> <span style=''>recover</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>macromolecules</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneous</span> <span style=''>samples</span> <span style=''>where</span> <span style=''>multiple</span> <span style=''>types</span> <span style=''>or</span> <span style=''>multiple</span> <span style=''>conformations</span> <span style=''>are</span> <span style=''>mixed</span> <span style=''>together</span> <span style=''>Indeed</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>many</span> <span style=''>tools</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>for</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>multiple</span> <span style=''>discrete</span> <span style=''>classes</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>molecules</span> <span style=''>mixed</span> <span style=''>together</span> <span style=''>in</span> <span style=''>a</span> <span style=''>cryo</span> <span style=''>EM</span> <span style='background-color:rgba(0, 255, 0, 0.4259259259259259);'>experiment</span> <span style=''>However</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interesting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>have</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuum</span> <span style=''>of</span> <span style=''>conformations</span> <span style=''>which</span> <span style=''>do</span> <span style=''>not< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Localized</span> <span style=''>Spatio</span> <span style=''>Temporal</span> <span style=''>Models</span> <span style=''>From</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Streaming</span> <span style=''>Data</span> <br/><br/><span style=''>We</span> <span style=''>address</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicting</span> <span style=''>spatio</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>with</span> <span style=''>temporal</span> <span style=''>patterns</span> <span style=''>that</span> <span style=''>vary</span> <span style=''>across</span> <span style=''>spatial</span> <span style=''>regions</span> <span style=''>when</span> <span style=''>data</span> <span style=''>is</span> <span style=''>obtained</span> <span style=''>as</span> <span style=''>a</span> <span style=''>stream</span> <span style=''>That</span> <span style=''>is</span> <span style=''>when</span> <span style=''>the</span> <span style=''>training</span> <span style=''>dataset</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>augmented</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequentially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>localized</span> <span style=''>spatio</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>model</span> <span style=''>of</span> <span style=''>the</span> <span style=''>process</span> <span style=''>that</span> <span style=''>can</span> <span style=''>capture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>spatially</span> <span style=''>varying</span> <span style=''>temporal</span> <span style=''>periodicities</span> <span style=''>in</span> <span style=''>the</span> <span style=''>data</span> <span style=''>We</span> <span style=''>then</span> <span style=''>apply</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>fitting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>which</span> <span style=''>yields</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>updated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequentially</span> <span style=''>with</span> <span style=''>each</span> <span style=''>new</span> <span style=''>data</span> <span style=''>point</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluated</span> <span style=''>using</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>and</span> <span style=''>real</span> <span style=''>climate</span> <span style=''>data</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>its</span> <span style=''>ability</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accurately</span> <span style=''>predict</span> <span style=''>data</span> <span style=''>missing</span> <span style=''>in</span> <span style=''>spatial</span> <span style=''>regions</span> <span style=''>over</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Permutation</span> <span style=''>based</span> <span style=''>Model</span> <span style=''>for</span> <span style=''>Crowd</span> <span style=''>Labeling</span> <span style=''>Optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Robustness</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>denoising</span> <span style=''>of</span> <span style=''>crowd</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>is</span> <span style=''>a</span> <span style=''>task</span> <span style=''>that</span> <span style=''>has</span> <span style=''>gained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increased</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significance</span> <span style=''>with</span> <span style=''>the</span> <span style=''>advent</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>crowdsourcing</span> <span style='background-color:rgba(0, 255, 0, 0.7333333333333334);'>platforms</span> <span style=''>and</span> <span style=''>massive</span> <span style=''>datasets</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>permutation</span> <span style=''>based</span> <span style=''>model</span> <span style=''>for</span> <span style=''>crowd</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>that</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>common</span> <span style=''>Dawid</span> <span style=''>Skene</span> <span style=''>model</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style=''>error</span> <span style=''>metric</span> <span style=''>by</span> <span style=''>which</span> <span style=''>to</span> <span style=''>compare</span> <span style='background-color:rgba(0, 255, 0, 0.3315217391304348);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.6344086021505376);'>estimators</span> <span style=''>Working</span> <span style=''>in</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3357664233576642);'>dimensional</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.648148148148148);'>asymptotic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>both</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>workers</span> <span style=''>and</span> <span style=''>tasks</span> <span style=''>to</span> <span style=''>scale</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>optimal</span> <span style=''>rates</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.347945205479452);'>convergence</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>permutation</span> <span style=''>based</span> <span style=''>model</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>permutation</span> <span style=''>based</span> <span style=''>model</span> <span style=''>offer ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Sequential</span> <span style=''>Dynamic</span> <span style=''>Decision</span> <span style=''>Making</span> <span style=''>with</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Nets</span> <span style=''>on</span> <span style=''>a</span> <span style=''>Test</span> <span style=''>Time</span> <span style=''>Budget</span> <br/><br/><span style=''>Deep</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>(DNN)</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>hold</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>(RL)</span> <span style=''>and</span> <span style=''>have</span> <span style=''>already</span> <span style=''>shown</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>remarkable</span> <span style=''>gains</span> <span style=''>over</span> <span style=''>state</span> <span style=''>of</span> <span style=''>art</span> <span style=''>methods</span> <span style=''>in</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>DNN</span> <span style=''>methods</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributed</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leveraging</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>abundance</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>data</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>Q</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>and</span> <span style=''>policy</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>without</span> <span style=''>the</span> <span style=''>need</span> <span style=''>for</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Nevertheless</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deployment</span> <span style=''>of</span> <span style=''>DNN</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictors</span> <span style=''>with</span> <span style=''>very</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>can</span> <span style=''>pose</span> <span style=''>an</span> <span style=''>issue</span> <span style=''>due</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>and</span> <span style=''>other</span> <span style=''>resource</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>at</span> <span style=''>test</span> <span style=''>time</span> <span style=''>in</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>for</span> <span st ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10218716385801363)
# 	segmentation (0.07350304768734313)
# 	processing (0.10899964144854786)
# 	knowledge (0.1276443169594837)
# 	experimental (0.13624955181068482)
# 	information (0.2491932592326999)
# 	detection (0.11903908210828254)
# 	different (0.26353531731803514)
# 	recognition (0.12800286841161707)
# 	convolutional (0.14198637504481892)
#
# Some Statistics words are:
# 	stochastic (0.13127797115862755)
# 	estimation (0.1636001989060169)
# 	variables (0.13823968175037296)
# 	theoretical (0.14868224763799104)
# 	algorithm (0.399801093983093)
# 	distribution (0.18746892093485829)
# 	statistical (0.16310293386374938)
# 	dimensional (0.18199900546991546)
# 	inference (0.19393336648433615)
# 	regression (0.18000994530084535)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b281fa0c-b78f-4c2d-94b4-49d9e9f855c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b281fa0c-b78f-4c2d-94b4-49d9e9f855c7")) {                    Plotly.newPlot(                        "b281fa0c-b78f-4c2d-94b4-49d9e9f855c7",                        [{"x":["approximation","inference","stationary","constraints","generated","intractable","approximate","sequential","convergent","experiments","synthetic","converges","similarly","regression","alternative","expectation","algorithm","propagation","partition","principal","nonparametric","stochastic","particularly","dependent","algorithms","component","considering","investigate","properties","convergence","theoretical","generalization","computational","complexity","distributed","reproducing","including","regularization","different","perceptions","community","recognition","processes","established","discriminate","segmentation","observers","significant","retention","scalability","extraction","systematic","supervoxels","perception","typically","potentially","detection","underlying","representation","decompositions","sophisticated","furthermore","explosion","semantics","intermediate","ultimately","processing","supervoxel","extensive","computation","introduce","polynomial","validated","guaranteed","predefined","agreement","splitting","overlapped","performance","subgraphs","framework","effectively","iterations","optimization","experimental","solutions","representations","introduced","strategies","knowledge","probabilities","ontologies","complications","demonstrates","vocabularies","formalized","significantly","distributions","debugging","diagnoses","demonstrated","superiority","scenarios","information","available","localization","efficient","interactive","effective","important","evaluation","application","performing","inappropriate","identified","qualities","selection","experimented","understanding","prerequisite","formulating","measurements","diagnosis","exploited","especially","descriptions","approaches","probability","observations","principle","described","resembling","analysing","regarding","outstanding","activation","artifacts","functioning","mechanisms","perceptrons","denoising","procedure","considered","architectures","artefactual","preprocessing","evaluations","relevance","comparing","robustness","prediction","parameter","conditions","compensating","initialization","investigating","alignment","pretraining","combination","recognizing","intuitively","excellent","evaluates","benchmark","performances","challenging","classification","architecture","effectiveness","demonstrate","biometrics","correlation","individual","transferring","correlated","applications","description","identification","representational","curriculum","attributes","advantages","performed","attribute","metaheuristic","earthquake","strengthen","reduction","connectivity","unnecessary","facilitate","estimated","reasoning","reasonable","transportation","investment","therefore","numerical","dimension","dependency","determining","neuroimaging","observation","compression","hierarchical","structure","suitability","principled","determine","empirical","criterion","asymptotic","dimensionality","clustering","examining","minimizes","continuous","automatically","generally","increasingly","characteristic","dirichlet","interests","streaming","thousands","accurately","meaningful","identical","developed","questions","expository","mathematicians","mathematics","primarily","exposition","collected","elsewhere","reference","philosophy","elementary","mathematician","suggested","substantial","justification","highlight","particular","directions","researchers","introduction","relatively","motivation","discovering","interaction","relationsh ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	contrasting
# 	distributionally
# 	convolved
# 	organised
# 	robustification
# 	monotonicity
# 	irreducible
# 	subroutines
# 	faithfulness
# 	inhibited
# 	spectrometry
# 	inspecting
# 	hoeffding
# 	nucleotide
# 	nonconvexity
# 	methylation
# 	idealized
# 	explodingvanishing
# 	distinguishability
# 	heteroscedastic
# Some words which never appear in Statistics papers:
# 	perceptions
# 	observers
# 	supervoxels
# 	supervoxel
# 	experimented
# 	prerequisite
# 	earthquake
# 	mathematicians
# 	mathematician
# 	morbidity
# 	processor
# 	multiprocessor
# 	entertainment
# 	operative
# 	endomicroscopy
# 	nondiagnostic
# 	portability
# 	visuomotor
# 	sensorimotor
# 	compensation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.081759068076058e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7558333333333334
